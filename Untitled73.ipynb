# %% [markdown]
# <a href="https://colab.research.google.com/github/Mishra-code308/Task-3/blob/main/Untitled73.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/USA accident by state.csv")
print(df.shape)
df.head()
# Out:
# (600, 5)
#      State  Month  NumberOfAccidents  Fatalities  SeriousInjuries
# 0  State_1      1               4817          24              178
# 1  State_1      2               2765          46              180
# 2  State_1      3                343          37               63
# 3  State_1      4               3258          24                6
# 4  State_1      5               1972          17              168

# %%
# Select top 10 states
top_10_states = state_accidents.head(10)

# Bar plot for top 10 states
top_10_states.plot(kind='bar', figsize=(12,6), title='Top 10 States by Number of Accidents', color='skyblue')
plt.ylabel("Number of Accidents")
plt.xlabel("State")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Group by month and count accidents
monthly_accidents = df.groupby('Month')['NumberOfAccidents'].sum()

# Plot monthly accidents
plt.figure(figsize=(10, 6))
monthly_accidents.plot(kind='line', marker='o', title='Monthly Trend of Accidents')
plt.xlabel("Month")
plt.ylabel("Number of Accidents")
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %%
# Top 10 states by Fatalities and Serious Injuries
top_10_fatal_injuries = fatal_injuries.head(10)

top_10_fatal_injuries.plot(kind='bar', figsize=(12,6), stacked=True, title="Top 10 States by Fatalities and Serious Injuries")
plt.ylabel("Number of People")
plt.xlabel("State")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
correlation = df[["NumberOfAccidents", "Fatalities", "SeriousInjuries"]].corr()

sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
import pandas as pd
import plotly.express as px

# Group by state (if needed)
state_data = df.groupby("State")[["NumberOfAccidents", "Fatalities", "SeriousInjuries"]].sum().reset_index()

# Create Choropleth map
fig = px.choropleth(
    state_data,
    locations='State',
    locationmode='USA-states',
    color='NumberOfAccidents',
    color_continuous_scale="Reds",
    scope="usa",
    hover_data=["Fatalities", "SeriousInjuries"],
    title="Total Number of Accidents by State in the US"
)

fig.update_layout(geo=dict(bgcolor='rgba(0,0,0,0)'), title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
